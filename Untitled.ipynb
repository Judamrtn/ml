# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Position_Salaries.csv')
df.head()
# Out:
#             Position  Level  Salary
# 0   Business Analyst      1   45000
# 1  Junior Consultant      2   50000
# 2  Senior Consultant      3   60000
# 3            Manager      4   80000
# 4    Country Manager      5  110000

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Position  10 non-null     object
#  1   Level     10 non-null     int64
#  2   Salary    10 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 372.0+ bytes
# Position    0
# Level       0
# Salary      0
# dtype: int64

# %%
X = df.iloc[: ,1: -1].values
Y = df.iloc[: , -1].values

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X, Y)
# Out:
# LinearRegression()

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree=4)
X_poly = poly_reg.fit_transform(X)

lin_reg_2 = LinearRegression()
lin_reg_2.fit(X_poly, Y)
# Out:
# LinearRegression()

# %%
lin_reg.predict([[3.5]])
# Out:
# array([87742.42424242])

# %%
poly_pred = lin_reg_2.predict(poly_reg.fit_transform([[3.5]]))
print(poly_pred)
# Out:
# [77125.1274767]

# %%
plt.scatter(X, Y, color='red')
plt.plot(X , lin_reg.predict(X), color='green')
plt.title('truth or bullf(linear regression)')
plt.xlabel('position level')
plt.ylabel('salary level')
plt.show()

# %%
plt.scatter(X , Y, color='red')
plt.plot(X, lin_reg_2.predict(X_ploy), color='blue')
plt.title('truth or bluff (polynomial regression)')
plt.xlabel('postion')
plt.ylabel('salary')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 plt.scatter(X , Y, color='red')
# ----> 2 plt.plot(X, lin_reg_2.predict(X_ploy), color='blue')
#       3 plt.title('truth or bluff (polynomial regression)')
#       4 plt.xlabel('postion')
#
# NameError: name 'X_ploy' is not defined
